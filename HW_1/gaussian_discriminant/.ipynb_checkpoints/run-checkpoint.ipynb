# %% [markdown]
# # Gaussian Discriminant Analysis and MLE
# *Complete and hand in this completed worksheet (including its outputs and any supporting code outside of the worksheet) with your assignment submission. Please check the pdf file for more details.*
#
# In this exercise you will:
#
# - implement the calculation of **gaussian posterior probability** of GDA
# - find appropriate tuples of parameters for variout kinds of **decision boundary**

# %%
# some basic imports
import numpy as np
# %matplotlib notebook
import matplotlib
import matplotlib.pyplot as plt
import math
from plot_ex1 import plot_ex1, figure

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ### Decision boundaries are plotted in the figure variable. You may need to refer to it after every plot

# %%
# mu: 2x1 matrix, e.g. np.array([[0,0]]).T
# Sigma: 2x2 matrix e.g. nnp.array([[1, 0], [0, 1]]).T
# phi: a number e.g 0.5

# change the value for specific decision boundary

mu0 = np.array([[0, 0]])
Sigma0 = np.array([[1, 0], [0, 1]])
mu1 = np.array([[5, 5]])
Sigma1 = np.array([[1, 0], [0, 1]])
phi = 0.5

# begin answer
# end answer

plot_ex1(mu0, Sigma0, mu1, Sigma1, phi, 'Line', 1)
figure
# Out:
# 1270606
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-44-d0791ccde60f> in <module>
#      14 # end answer
#      15
# ---> 16 plot_ex1(mu0, Sigma0, mu1, Sigma1, phi, 'Line', 1)
#      17 figure
#
# ~\Desktop\Data Mining\HW_1\gaussian_discriminant\plot_ex1.py in plot_ex1(mu0, Sigma0, mu1, Sigma1, phi, fig_title, pos)
#      33     Sigma[:, :, 0] = Sigma0
#      34     Sigma[:, :, 1] = Sigma1
# ---> 35     pos_prob = gaussian_pos_prob(xy.T, np.hstack((mu0, mu1)), Sigma, np.array([1 - phi, phi]))
#      36     pos_prob = pos_prob[:, 0]
#      37     image_size = xs.shape
#
# ~\Desktop\Data Mining\HW_1\gaussian_discriminant\gaussian_pos_prob.py in gaussian_pos_prob(X, Mu, Sigma, Phi)
#      29         for j in range(0, K-1):
#      30             p1 = 1 / (2 * math.pi * math.sqrt(np.linalg.det(Sigma[:, :, j])))
# ---> 31             p2 = np.dot((x - Mu[:, j]).T,  np.matrix(Sigma[:, :, j]).I)
#      32             p3 = np.dot(p2, (x - Mu[:, j]))
#      33             p4 = math.exp(-1/2 * p3)
#
# ValueError: shapes (1270606,) and (2,2) not aligned: 1270606 (dim 0) != 2 (dim 0)

# %%
mu0 = np.array([[0, 0]])
Sigma0 = np.array([[1, 0], [0, 1]])
mu1 = np.array([[1, 1]])
Sigma1 = np.array([[1, 0], [0, 1]])
phi = 0.5

# begin answer
# end answer

plot_ex1(mu0, Sigma0, mu1, Sigma1, phi, 'Line (one side)', 2)
figure
# Out:
# 457646
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-35-67abfd998159> in <module>
#       8 # end answer
#       9
# ---> 10 plot_ex1(mu0, Sigma0, mu1, Sigma1, phi, 'Line (one side)', 2)
#      11 figure
#
# ~\Desktop\Data Mining\HW_1\gaussian_discriminant\plot_ex1.py in plot_ex1(mu0, Sigma0, mu1, Sigma1, phi, fig_title, pos)
#      33     Sigma[:, :, 0] = Sigma0
#      34     Sigma[:, :, 1] = Sigma1
# ---> 35     pos_prob = gaussian_pos_prob(xy.T, np.hstack((mu0, mu1)), Sigma, np.array([1 - phi, phi]))
#      36     pos_prob = pos_prob[:, 0]
#      37     image_size = xs.shape
#
# ~\Desktop\Data Mining\HW_1\gaussian_discriminant\gaussian_pos_prob.py in gaussian_pos_prob(X, Mu, Sigma, Phi)
#      29         for j in range(0, K-1):
#      30             p1 = 1 / (2 * math.pi * math.sqrt(np.linalg.det(Sigma[:, :, j])))
# ---> 31             p2 = np.dot((x - Mu[:, j]).T,  np.matrix(Sigma[:, :, j]).I)
#      32             p3 = np.dot(p2, (x - Mu[:, j]))
#      33             p4 = math.exp(-1/2 * p3)
#
# ValueError: shapes (457646,) and (2,2) not aligned: 457646 (dim 0) != 2 (dim 0)

# %%
mu0 = np.array([[0, 0]])
Sigma0 = np.array([[2, 0], [0, 5]])
mu1 = np.array([[2, 2]])
Sigma1 = np.array([[3, 0], [0, 5]])
phi = 0.5

# begin answer
# end answer

plot_ex1(mu0, Sigma0, mu1, Sigma1, phi, 'Parabalic', 3)
figure
# Out:
# 1808001
# [[-3.76289521e-08  0.00000000e+00]
#  [-3.87080050e-08  0.00000000e+00]
#  [-3.98160410e-08  0.00000000e+00]
#  ...
#  [ 1.65937845e-12  0.00000000e+00]
#  [ 1.59630328e-12  0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00]]
# <img src="data:image/png;base64,..." width="1599.2593722350066">

# %%
mu0 = 0
Sigma0 = 0
mu1 = 0
Sigma1 = 0
phi = 0

# begin answer
# end answer

plot_ex1(mu0, Sigma0, mu1, Sigma1, phi, 'Hyperbola', 4)
figure
# Out:
# <img src="data:image/png;base64,..." width="1600">

# %%
xmu0 = 0
Sigma0 = 0
mu1 = 0
Sigma1 = 0
phi = 0

# begin answer
# end answer

plot_ex1(mu0, Sigma0, mu1, Sigma1, phi, 'Two parallel lines.', 5)
figure
# Out:
# <img src="data:image/png;base64,..." width="1600">

# %%
mu0 = 0
Sigma0 = 0
mu1 = 0
Sigma1 = 0
phi = 0

# begin answer
# end answer

plot_ex1(mu0, Sigma0, mu1, Sigma1, phi, 'Circle', 6)
figure
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-572b92c65b77> in <module>
#       8 # end answer
#       9
# ---> 10 plot_ex1(mu0, Sigma0, mu1, Sigma1, phi, 'Circle', 6)
#      11 figure
#
# NameError: name 'plot_ex1' is not defined

# %%
mu0 = 0
Sigma0 = 0
mu1 = 0
Sigma1 = 0
phi = 0

# begin answer
# end answer

plot_ex1(mu0, Sigma0, mu1, Sigma1, phi, 'Ellipsoid', 7)
figure
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-e31517c83b1e> in <module>
#       8 # end answer
#       9
# ---> 10 plot_ex1(mu0, Sigma0, mu1, Sigma1, phi, 'Ellipsoid', 7)
#      11 figure
#
# NameError: name 'plot_ex1' is not defined

# %%
mu0 = 0
Sigma0 = 0
mu1 = 0
Sigma1 = 0
phi = 0


# begin answer
# end answer


plot_ex1(mu0, Sigma0, mu1, Sigma1, phi, 'No boundary', 8)
figure
# Out:
# <img src="data:image/png;base64,..." width="1600">

# %%
figure.savefig("hw1_gaussian_discriminant.png")
